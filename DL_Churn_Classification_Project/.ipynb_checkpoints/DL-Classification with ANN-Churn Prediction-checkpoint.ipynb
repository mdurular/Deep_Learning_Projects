# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# ## Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.

# %% [markdown]
# ## Improt Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# ## Indest Data

# %%
df = pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.000              1          1               1
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# 4        79084.100       0

# %% [markdown]
# **The features in the given dataset are:**
#
# **rownumber**: Row Numbers from 1 to 10000.
#
# **customerid**: A unique ID that identifies each customer.
#
# **surname**: The customer’s surname.
#
# **creditscore**: A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
#
# **geography**: The country from which the customer belongs to.
#
# **Gender**: The customer’s gender: Male, Female
#
# **Age**: The customer’s current age, in years, at the time of being customer.
#
# **tenure**: The number of years for which the customer has been with the bank.
#
# **balance**: Bank balance of the customer.
#
# **numofproducts**: the number of bank products the customer is utilising.
#
# **hascrcard**: The number of credit cards given to the customer by the bank.
#
# **isactivemember**: Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
#
# **exited**: Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# There are 14 columns in the dataset

# %%
df.columns[-1] # last column is target
# Out:
# 'Exited'

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.info() # to know the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe().T # to see the summary of the dataframe
# Out:
#                     count         mean       std          min          25%  \
# RowNumber       10000.000     5000.500  2886.896        1.000     2500.750
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# RowNumber           5000.500     7500.250    10000.000
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.isnull().sum() # check for missing values
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum() # check for duplicate values
# Out:
# 0

# %%
# we didn't require customerID, Surname  and Rownumber so we drop it

df = df.drop(["CustomerId","RowNumber","Surname",],axis=1)

# %%
#numerical variables

num = list(df.select_dtypes(include=[np.number]).columns)

#categorical variables

cat = list(df.select_dtypes(include='object').columns)

print(cat)

print(num)
# Out:
# ['Geography', 'Gender']
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %%
for i in cat:
    print(df[i].value_counts())
    print("------")
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# ------
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# ------

# %%
df.Exited.value_counts() # Target values
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
labels = 'Exited', 'Retained'
import random
n = 40
color = ["#" + ''.join([random.choice('0123456789ABCDEF')
                        for j in range(6)]) for i in range(n)]
plt.figure(figsize=(10,8))
explode = [0,0.1]
plt.pie(df['Exited'].value_counts(), labels=labels,explode=explode,autopct='%1.1f%%', colors=color, startangle=45)
plt.title('Churn Distribution');

# %%
 # We first review the 'Status' relation with categorical variables
fig, axarr = plt.subplots(2, 2, figsize=(20, 12))
sns.countplot(x='Geography', hue = 'Exited',data = df, ax=axarr[0][0])
sns.countplot(x='Gender', hue = 'Exited',data = df, ax=axarr[0][1])
sns.countplot(x='HasCrCard', hue = 'Exited',data = df, ax=axarr[1][0])
sns.countplot(x='IsActiveMember', hue = 'Exited',data = df, ax=axarr[1][1]);

# %%
ax = sns.countplot(x='Exited',data=df,hue='Gender')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1]);

# %%
ax = sns.countplot(x='Exited',data=df, hue='HasCrCard')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1]);

# %%
ax = sns.countplot(x='Exited',data=df, hue='Geography')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2]);

# %%
ax = sns.countplot(df["Tenure"]);
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize=(16,6))
ax = sns.histplot(data=df, x="Age",bins=20, hue="Exited", kde=True);
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize = (8,10))
df.corr()["Exited"].sort_values().drop("Exited").plot(kind = "barh")
ax.bar_label(ax.containers[0]);

# %%
plt.figure(figsize=(14, 10))

# Getting the Upper Triangle of the co-relation matrix
matrix = np.triu(df.corr())

# using the upper triangle matrix as mask 
sns.heatmap(df.corr(), annot=True, cmap = sns.cubehelix_palette(20), mask=matrix)

plt.xticks(rotation=45);

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in num:
    if feature != "Exited":
        index += 1
        plt.subplot(4, 3, index)
        sns.boxplot(x='Exited', y=feature, data=df)

# %%
sns.pairplot(df, hue="Exited", corner=True);

# %%
sns.swarmplot(y="Age", x="Geography", hue="Exited", data=df);

# %%
sns.swarmplot(y="Age", x="Gender", hue="Exited", data=df);

# %%
df.insert(11, 'churn', df['Exited'])

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.000              1
# 1          608     Spain  Female   41       1  83807.860              1
# 2          502    France  Female   42       8 159660.800              3
# 3          699    France  Female   39       1      0.000              2
# 4          850     Spain  Female   43       2 125510.820              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  churn
# 0          1               1       101348.880       1      1
# 1          0               1       112542.580       0      0
# 2          1               0       113931.570       1      1
# 3          0               0        93826.630       0      0
# 4          1               1        79084.100       0      0

# %%
df.drop('Exited', axis=1, inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.000              1
# 1          608     Spain  Female   41       1  83807.860              1
# 2          502    France  Female   42       8 159660.800              3
# 3          699    France  Female   39       1      0.000              2
# 4          850     Spain  Female   43       2 125510.820              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  churn
# 0          1               1       101348.880      1
# 1          0               1       112542.580      0
# 2          1               0       113931.570      1
# 3          0               0        93826.630      0
# 4          1               1        79084.100      0

# %%
df = pd.get_dummies(df, drop_first =True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.000              1          1
# 1          608   41       1  83807.860              1          0
# 2          502   42       8 159660.800              3          1
# 3          699   39       1      0.000              2          0
# 4          850   43       2 125510.820              1          1
#
#    IsActiveMember  EstimatedSalary  churn  Geography_Germany  Geography_Spain  \
# 0               1       101348.880      1                  0                0
# 1               1       112542.580      0                  0                1
# 2               0       113931.570      1                  0                0
# 3               0        93826.630      0                  0                0
# 4               1        79084.100      0                  0                1
#
#    Gender_Male
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# ## Preprocessing of Data
# - Train | Test Split, Scalling

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('churn', axis = 1)
y = df['churn']

# %%
seed = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size=0.2, random_state=seed)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape)   
print(X_test.shape)
# Out:
# (8000, 11)
# (2000, 11)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000,)
# (2000,)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# ### Import related libraries

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from scikeras.wrappers import KerasClassifier, KerasRegressor
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold 
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ### Creating Model

# %% [markdown]
# ### without class_weigth

# %%
""" class_weight: Optional dictionary mapping class indices (integers)
        to a weight (float) value, used for weighting the loss function
        (during training only).
        This can be useful to tell the model to
        "pay more attention" to samples from
        an under-represented class."""


# define sequential model

model = Sequential()
model.add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
model.add(Dense(10, activation='relu'))
model.add(Dense(5,  activation = 'relu'))
model.add(Dense(1, activation='sigmoid')) # we use sigmoid for binary output
model.summary()


# compile the model

model.compile(optimizer = 'adam',loss = 'binary_crossentropy', metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data
model.fit(x = X_train, y = y_train, epochs=250, validation_split = 0.1, batch_size=32,verbose=1,callbacks = [early_stop])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 15)                180
#
#  dense_5 (Dense)             (None, 10)                160
#
#  dense_6 (Dense)             (None, 5)                 55
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 225/225 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7722 - val_loss: 0.4690 - val_accuracy: 0.8100
# Epoch 2/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.7964 - val_loss: 0.4473 - val_accuracy: 0.8125
# Epoch 3/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.8031 - val_loss: 0.4368 - val_accuracy: 0.8150
# Epoch 4/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.8071 - val_loss: 0.4324 - val_accuracy: 0.8213
# Epoch 5/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4382 - accuracy: 0.8086 - val_loss: 0.4237 - val_accuracy: 0.8238
# Epoch 6/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4333 - accuracy: 0.8131 - val_loss: 0.4206 - val_accuracy: 0.8275
# Epoch 7/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.8107 - val_loss: 0.4159 - val_accuracy: 0.8300
# Epoch 8/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4291 - accuracy: 0.8108 - val_loss: 0.4143 - val_accuracy: 0.8263
# Epoch 9/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4248 - accuracy: 0.8133 - val_loss: 0.4071 - val_accuracy: 0.8288
# Epoch 10/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8169 - val_loss: 0.4023 - val_accuracy: 0.8338
# Epoch 11/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8176 - val_loss: 0.3993 - val_accuracy: 0.8400
# Epoch 12/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8172 - val_loss: 0.3878 - val_accuracy: 0.8438
# Epoch 13/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8225 - val_loss: 0.3802 - val_accuracy: 0.8500
# Epoch 14/250
# 225/225 [==============================] - 0s 993us/step - loss: 0.3931 - accuracy: 0.8288 - val_loss: 0.3732 - val_accuracy: 0.8487
# Epoch 15/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8331 - val_loss: 0.3651 - val_accuracy: 0.8525
# Epoch 16/250
# 225/225 [==============================] - 0s 996us/step - loss: 0.3784 - accuracy: 0.8360 - val_loss: 0.3609 - val_accuracy: 0.8500
# Epoch 17/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3739 - accuracy: 0.8382 - val_loss: 0.3534 - val_accuracy: 0.8475
# Epoch 18/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3675 - accuracy: 0.8449 - val_loss: 0.3487 - val_accuracy: 0.8562
# Epoch 19/250
# 225/225 [==============================] - 0s 990us/step - loss: 0.3640 - accuracy: 0.8443 - val_loss: 0.3555 - val_accuracy: 0.8525
# Epoch 20/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3628 - accuracy: 0.8496 - val_loss: 0.3443 - val_accuracy: 0.8562
# Epoch 21/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.
250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8622 - val_loss: 0.3099 - val_accuracy: 0.8662
# Epoch 127/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3302 - accuracy: 0.8618 - val_loss: 0.3102 - val_accuracy: 0.8625
# Epoch 128/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8624 - val_loss: 0.3095 - val_accuracy: 0.8700
# Epoch 129/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3299 - accuracy: 0.8615 - val_loss: 0.3121 - val_accuracy: 0.8700
# Epoch 130/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8624 - val_loss: 0.3182 - val_accuracy: 0.8675
# Epoch 131/250
# 225/225 [==============================] - 0s 982us/step - loss: 0.3307 - accuracy: 0.8614 - val_loss: 0.3094 - val_accuracy: 0.8650
# Epoch 132/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8624 - val_loss: 0.3069 - val_accuracy: 0.8700
# Epoch 133/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3299 - accuracy: 0.8628 - val_loss: 0.3148 - val_accuracy: 0.8687
# Epoch 134/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3313 - accuracy: 0.8621 - val_loss: 0.3106 - val_accuracy: 0.8650
# Epoch 135/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8618 - val_loss: 0.3080 - val_accuracy: 0.8750
# Epoch 136/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3299 - accuracy: 0.8633 - val_loss: 0.3092 - val_accuracy: 0.8650
# Epoch 137/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3290 - accuracy: 0.8628 - val_loss: 0.3101 - val_accuracy: 0.8725
# Epoch 138/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8637 - val_loss: 0.3085 - val_accuracy: 0.8612
# Epoch 139/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8617 - val_loss: 0.3083 - val_accuracy: 0.8662
# Epoch 140/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3290 - accuracy: 0.8617 - val_loss: 0.3076 - val_accuracy: 0.8687
# Epoch 141/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3293 - accuracy: 0.8635 - val_loss: 0.3079 - val_accuracy: 0.8662
# Epoch 142/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8624 - val_loss: 0.3119 - val_accuracy: 0.8637
# Epoch 143/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8631 - val_loss: 0.3162 - val_accuracy: 0.8575
# Epoch 144/250
# 225/225 [==============================] - 0s 984us/step - loss: 0.3290 - accuracy: 0.8640 - val_loss: 0.3085 - val_accuracy: 0.8700
# Epoch 145/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8647 - val_loss: 0.3078 - val_accuracy: 0.8625
# Epoch 146/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.8621 - val_loss: 0.3062 - val_accuracy: 0.8700
# Epoch 147/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8633 - val_loss: 0.3091 - val_accuracy: 0.8700
# Epoch 148/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8632 - val_loss: 0.3081 - val_accuracy: 0.8637
# Epoch 149/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3286 - accuracy: 0.8643 - val_loss: 0.3067 - val_accuracy: 0.8712
# Epoch 150/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3293 - accuracy: 0.8639 - val_loss: 0.3093 - val_accuracy: 0.8675
# Epoch 151/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8618 - val_loss: 0.3094 - val_accuracy: 0.8712
# Epoch 152/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3291 - accuracy: 0.8622 - val_loss: 0.3103 - val_accuracy: 0.8687
# Epoch 153/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8622 - val_loss: 0.3089 - val_accuracy: 0.8650
# Epoch 154/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3286 - accuracy: 0.8618 - val_loss: 0.3122 - val_accuracy: 0.8637
# Epoch 155/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8635 - val_loss: 0.3101 - val_accuracy: 0.8675
# Epoch 156/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3297 - accuracy: 0.8639 - val_loss: 0.3082 - val_accuracy: 0.8700
# Epoch 157/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3291 - accuracy: 0.8629 - val_loss: 0.3087 - val_accuracy: 0.8675
# Epoch 158/250
# 225/225 [==============================] - 0s 973us/step - loss: 0.3293 - accuracy: 0.8621 - val_loss: 0.3146 - val_accuracy: 0.8612
# Epoch 159/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3272 - accuracy: 0.8629 - val_loss: 0.3119 - val_accuracy: 0.8712
# Epoch 160/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8631 - val_loss: 0.3088 - val_accuracy: 0.8687
# Epoch 161/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3285 - accuracy: 0.8640 - val_loss: 0.3086 - val_accuracy: 0.8700
# Epoch 162/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 0.8644 - val_loss: 0.3082 - val_accuracy: 0.8662
# Epoch 163/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3285 - accuracy: 0.8622 - val_loss: 0.3153 - val_accuracy: 0.8712
# Epoch 164/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8637 - val_loss: 0.3124 - val_accuracy: 0.8650
# Epoch 165/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8629 - val_loss: 0.3096 - val_accuracy: 0.8737
# Epoch 166/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3269 - accuracy: 0.8631 - val_loss: 0.3182 - val_accuracy: 0.8737
# Epoch 166: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 15)                180
#
#  dense_5 (Dense)             (None, 10)                160
#
#  dense_6 (Dense)             (None, 5)                 55
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.538     0.772     0.469         0.810
# 1 0.471     0.796     0.447         0.812
# 2 0.456     0.803     0.437         0.815
# 3 0.446     0.807     0.432         0.821
# 4 0.438     0.809     0.424         0.824

# %%
loss_df.plot();

# %% [markdown]
# #### Evaluate

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3418 - accuracy: 0.8630
# [0.34177953004837036, 0.8629999756813049]

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.34177953004837036
# accuracy :  0.8629999756813049

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1503   90]
#  [ 184  223]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      1593
#            1       0.71      0.55      0.62       407
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.75      0.77      2000
# weighted avg       0.85      0.86      0.86      2000

# %% [markdown]
# ### with class_weigth
#
# Investigate how the "class_weight" hyper-parameter is used in a Neural Network.

# %% [markdown]
# https://datascience.stackexchange.com/questions/13490/how-to-set-class-weights-for-imbalanced-classes-in-keras

# %%
from sklearn.utils import class_weight

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 classes= np.unique(y_train),
                                                 y = y_train)

# %%
class_weights
# Out:
# array([0.62794349, 2.45398773])

# %%
""" class_weight: Optional dictionary mapping class indices (integers)
        to a weight (float) value, used for weighting the loss function
        (during training only).
        This can be useful to tell the model to
        "pay more attention" to samples from
        an under-represented class."""

# define sequential model

model_weighted  = Sequential()
model_weighted .add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
model_weighted .add(Dense(10, activation='relu'))
model_weighted .add(Dense(5,  activation = 'relu'))
model_weighted .add(Dense(1, activation='sigmoid')) # we use sigmoid for binary output
model_weighted .summary()


# compile the model
opt = Adam(lr = 0.005)

model_weighted .compile(optimizer = opt, loss = 'binary_crossentropy',metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data

class_weight = {0:0.62794349 , 1:2.45398773}

model_weighted .fit(x=X_train, y=y_train, epochs=250, batch_size=32, validation_split = 0.1, verbose=1, class_weight=class_weight,
          callbacks = [early_stop])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 15)                180
#
#  dense_21 (Dense)            (None, 10)                160
#
#  dense_22 (Dense)            (None, 5)                 55
#
#  dense_23 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 225/225 [==============================] - 1s 1ms/step - loss: 0.6421 - accuracy: 0.6701 - val_loss: 0.5208 - val_accuracy: 0.7475
# Epoch 2/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.6964 - val_loss: 0.5542 - val_accuracy: 0.7175
# Epoch 3/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.5419 - accuracy: 0.7299 - val_loss: 0.4757 - val_accuracy: 0.7713
# Epoch 4/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.5165 - accuracy: 0.7462 - val_loss: 0.4241 - val_accuracy: 0.8087
# Epoch 5/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4949 - accuracy: 0.7672 - val_loss: 0.4378 - val_accuracy: 0.7975
# Epoch 6/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4902 - accuracy: 0.7590 - val_loss: 0.4908 - val_accuracy: 0.7513
# Epoch 7/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4820 - accuracy: 0.7674 - val_loss: 0.4055 - val_accuracy: 0.8150
# Epoch 8/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7735 - val_loss: 0.4300 - val_accuracy: 0.7875
# Epoch 9/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.7812 - val_loss: 0.3880 - val_accuracy: 0.8188
# Epoch 10/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4737 - accuracy: 0.7714 - val_loss: 0.4189 - val_accuracy: 0.7937
# Epoch 11/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4679 - accuracy: 0.7861 - val_loss: 0.3910 - val_accuracy: 0.8313
# Epoch 12/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4704 - accuracy: 0.7860 - val_loss: 0.4482 - val_accuracy: 0.7800
# Epoch 13/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4704 - accuracy: 0.7829 - val_loss: 0.4368 - val_accuracy: 0.8050
# Epoch 14/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4681 - accuracy: 0.7864 - val_loss: 0.4529 - val_accuracy: 0.7738
# Epoch 15/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.7881 - val_loss: 0.4162 - val_accuracy: 0.8025
# Epoch 16/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4630 - accuracy: 0.7856 - val_loss: 0.4253 - val_accuracy: 0.7887
# Epoch 17/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4610 - accuracy: 0.7921 - val_loss: 0.4478 - val_accuracy: 0.7825
# Epoch 18/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4623 - accuracy: 0.7832 - val_loss: 0.4138 - val_accuracy: 0.8112
# Epoch 19/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4594 - accuracy: 0.7899 - val_loss: 0.4718 - val_accuracy: 0.7588
# Epoch 20/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4626 - accuracy: 0.7862 - val_loss: 0.4733 - val_accuracy: 0.7550
# Epoch 21/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4579 - accuracy: 0.7924 - val_loss: 0.4203 - val_accuracy: 0.8000
# Epoch 22/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7897 - val_loss: 0.4842 - val_accuracy: 0.7513
# Epoch 23/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.7826 - val_loss: 0.4056 - val_accuracy: 0.8087
# Epoch 24/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7904 - val_loss: 0.3978 - val_accuracy: 0.8300
# Epoch 25/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.7864 - val_loss: 0.4126 - val_accuracy: 0.8000
# Epoch 26/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.7903 - val_loss: 0.4180 - val_accuracy: 0.8012
# Epoch 27/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4569 - accuracy: 0.7953 - val_loss: 0.4111 - val_accuracy: 0.8087
# Epoch 28/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4571 - accuracy: 0.7925 - val_loss: 0.4569 - val_accuracy: 0.7588
# Epoch 29/250
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7949 - val_loss: 0.4779 - val_accuracy: 0.7525
# Epoch 29: early stopping

# %%
model_weighted .summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 15)                180
#
#  dense_21 (Dense)            (None, 10)                160
#
#  dense_22 (Dense)            (None, 5)                 55
#
#  dense_23 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model_weighted .history.history)
loss_df.head()
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.642     0.670     0.521         0.748
# 1 0.584     0.696     0.554         0.717
# 2 0.542     0.730     0.476         0.771
# 3 0.516     0.746     0.424         0.809
# 4 0.495     0.767     0.438         0.798

# %% [markdown]
# #### Evaluate

# %%
loss_df.plot();

# %%
model_weighted .evaluate(X_test, y_test, verbose=0)
# Out:
# [0.48616498708724976, 0.7549999952316284]

# %%
loss, accuracy = model_weighted.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.48616498708724976
# accuracy :  0.7549999952316284

# %%
y_pred = (model_weighted.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1186  407]
#  [  83  324]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1593
#            1       0.44      0.80      0.57       407
#
#     accuracy                           0.76      2000
#    macro avg       0.69      0.77      0.70      2000
# weighted avg       0.83      0.76      0.78      2000

# %% [markdown]
# ## GridSearchCV

# %%
def build_classifier(optimizer, learn_rate):
    classifier = Sequential()
    classifier.add(Dense(units = 15, activation = 'relu'))
    classifier.add(Dense(units = 10, activation = 'relu'))
    classifier.add(Dense(units = 5, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer(learn_rate), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
early_stop = EarlyStopping(monitor = "val_accuracy", mode = "auto", verbose = 1, patience = 15)

# %%
tf.random.set_seed(seed)

classifier_model = KerasClassifier(build_fn = build_classifier, validation_split = 0.1, epochs = 200)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, RMSprop, Adadelta, Nadam],
              'learn_rate': [0.001, 0.003, 0.005]}

grid_model = GridSearchCV(estimator = classifier_model,
                          param_grid = parameters,
                          scoring = 'accuracy',
                          cv = 10,
                          n_jobs = -1,
                          verbose = 1)



grid_model.fit(X_train, y_train, callbacks = [early_stop])
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# Epoch 1/200
# 225/225 [==============================] - 1s 1ms/step - loss: 0.4968 - accuracy: 0.7818 - val_loss: 0.4440 - val_accuracy: 0.8100
# Epoch 2/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.8106 - val_loss: 0.4141 - val_accuracy: 0.8300
# Epoch 3/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8332 - val_loss: 0.3527 - val_accuracy: 0.8587
# Epoch 4/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3720 - accuracy: 0.8481 - val_loss: 0.3484 - val_accuracy: 0.8625
# Epoch 5/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3643 - accuracy: 0.8512 - val_loss: 0.3567 - val_accuracy: 0.8537
# Epoch 6/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3599 - accuracy: 0.8499 - val_loss: 0.3315 - val_accuracy: 0.8650
# Epoch 7/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3560 - accuracy: 0.8582 - val_loss: 0.3287 - val_accuracy: 0.8650
# Epoch 8/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3567 - accuracy: 0.8544 - val_loss: 0.3326 - val_accuracy: 0.8650
# Epoch 9/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3535 - accuracy: 0.8576 - val_loss: 0.3290 - val_accuracy: 0.8650
# Epoch 10/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.8574 - val_loss: 0.3276 - val_accuracy: 0.8625
# Epoch 11/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8572 - val_loss: 0.3350 - val_accuracy: 0.8662
# Epoch 12/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3509 - accuracy: 0.8572 - val_loss: 0.3239 - val_accuracy: 0.8650
# Epoch 13/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8564 - val_loss: 0.3226 - val_accuracy: 0.8675
# Epoch 14/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8576 - val_loss: 0.3201 - val_accuracy: 0.8637
# Epoch 15/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3475 - accuracy: 0.8567 - val_loss: 0.3222 - val_accuracy: 0.8650
# Epoch 16/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3463 - accuracy: 0.8599 - val_loss: 0.3179 - val_accuracy: 0.8700
# Epoch 17/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3454 - accuracy: 0.8614 - val_loss: 0.3160 - val_accuracy: 0.8687
# Epoch 18/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3448 - accuracy: 0.8575 - val_loss: 0.3151 - val_accuracy: 0.8650
# Epoch 19/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3428 - accuracy: 0.8606 - val_loss: 0.3283 - val_accuracy: 0.8662
# Epoch 20/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8586 - val_loss: 0.3156 - val_accuracy: 0.8750
# Epoch 21/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.8603 - val_loss: 0.3222 - val_accuracy: 0.8675
# Epoch 22/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.8604 - val_loss: 0.3122 - val_accuracy: 0.8700
# Epoch 23/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3400 - accuracy: 0.8594 - val_loss: 0.3212 - val_accuracy: 0.8650
# Epoch 24/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3398 - accuracy: 0.8615 - val_loss: 0.3234 - val_accuracy: 0.8675
# Epoch 25/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8600 - val_loss: 0.3123 - val_accuracy: 0.8712
# Epoch 26/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3374 - accuracy: 0.8612 - val_loss: 0.3136 - val_accuracy: 0.8725
# Epoch 27/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3392 - accuracy: 0.8622 - val_loss: 0.3112 - val_accuracy: 0.8725
# Epoch 28/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3383 - accuracy: 0.8622 - val_loss: 0.3110 - val_accuracy: 0.8725
# Epoch 29/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3366 - accuracy: 0.8624 - val_loss: 0.3278 - val_accuracy: 0.8712
# Epoch 30/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3368 - accuracy: 0.8639 - val_loss: 0.3123 - val_accuracy: 0.8750
# Epoch 31/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3358 - accuracy: 0.8611 - val_loss: 0.3137 - val_accuracy: 0.8700
# Epoch 32/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8639 - val_loss: 0.3143 - val_accuracy: 0.8800
# Epoch 33/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8604 - val_loss: 0.3289 - val_accuracy: 0.8712
# Epoch 34/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.8619 - val_loss: 0.3071 - val_accuracy: 0.8700
# Epoch 35/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8650 - val_loss: 0.3144 - val_accuracy: 0.8750
# Epoch 36/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8612 - val_loss: 0.3123 - val_accuracy: 0.8725
# Epoch 37/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8624 - val_loss: 0.3137 - val_accuracy: 0.8712
# Epoch 38/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8610 - val_loss: 0.3117 - val_accuracy: 0.8763
# Epoch 39/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8617 - val_loss: 0.3168 - val_accuracy: 0.8712
# Epoch 40/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3343 - accuracy: 0.8631 - val_loss: 0.3148 - val_accuracy: 0.8712
# Epoch 41/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3334 - accuracy: 0.8615 - val_loss: 0.3094 - val_accuracy: 0.8725
# Epoch 42/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3342 - accuracy: 0.8601 - val_loss: 0.3180 - val_accuracy: 0.8675
# Epoch 43/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8639 - val_loss: 0.3176 - val_accuracy: 0.8788
# Epoch 44/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3309 - accuracy: 0.8608 - val_loss: 0.3126 - val_accuracy: 0.8800
# Epoch 45/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.8604 - val_loss: 0.3186 - val_accuracy: 0.8675
# Epoch 46/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.8631 - val_loss: 0.3164 - val_accuracy: 0.8737
# Epoch 47/200
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3302 - accuracy: 0.8632 - val_loss: 0.3081 - val_accuracy: 0.8775
# Epoch 47: early stopping
# GridSearchCV(cv=10,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x000002C8D9583D60>,
#              n_jobs=-1,
#              param_grid={'batch_size': [32, 64],
#                          'learn_rate': [0.001, 0.003, 0.005],
#                          'optimizer': [<class 'keras.optimizer_v2.adam.Adam'>,
#                                        <class 'keras.optimizer_v2.rmsprop.RMSprop'>,
#                                        <class 'keras.optimizer_v2.adadelta.Adadelta'>,
#                                        <class 'keras.optimizer_v2.nadam.Nadam'>]},
#              scoring='accuracy', verbose=1)

# %%
grid_model.best_score_
# Out:
# 0.858

# %%
grid_model.best_params_
# Out:
# {'batch_size': 32,
#  'learn_rate': 0.005,
#  'optimizer': keras.optimizer_v2.nadam.Nadam}

# %%
grid_result = pd.DataFrame(grid_model.cv_results_)[["mean_test_score", "std_test_score", "rank_test_score", "params"]].sort_values(by='rank_test_score')
grid_result
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 11            0.858           0.012                1
# 19            0.856           0.015                2
# 16            0.856           0.016                3
# 17            0.856           0.013                4
# 0             0.856           0.014                5
# 5             0.855           0.016                6
# 7             0.855           0.015                7
# 15            0.855           0.012                8
# 12            0.855           0.014                9
# 4             0.855           0.012               10
# 23            0.854           0.014               11
# 1             0.854           0.014               12
# 20            0.853           0.018               13
# 9             0.852           0.013               14
# 21            0.851           0.013               15
# 3             0.849           0.014               16
# 8             0.849           0.028               17
# 13            0.846           0.026               18
# 6             0.796           0.021               19
# 10            0.796           0.021               19
# 22            0.796           0.022               21
# 2             0.796           0.022               22
# 18            0.740           0.175               23
# 14            0.729           0.188               24
#
#                                                params
# 11  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 19  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 16  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 17  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 0   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 5   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 7   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 15  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 12  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 4   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 23  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 1   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 20  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 9   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 21  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 3   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 8   {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 13  {'batch_size': 64, 'learn_rate': 0.001, 'optim...
# 6   {'batch_size': 32, 'learn_rate': 0.003, 'optim...
# 10  {'batch_size': 32, 'learn_rate': 0.005, 'optim...
# 22  {'batch_size': 64, 'learn_rate': 0.005, 'optim...
# 2   {'batch_size': 32, 'learn_rate': 0.001, 'optim...
# 18  {'batch_size': 64, 'learn_rate': 0.003, 'optim...
# 14  {'batch_size': 64, 'learn_rate': 0.001, 'optim...

# %%
y_pred = (grid_model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1555   38]
#  [ 246  161]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      1593
#            1       0.81      0.40      0.53       407
#
#     accuracy                           0.86      2000
#    macro avg       0.84      0.69      0.72      2000
# weighted avg       0.85      0.86      0.84      2000

# %% [markdown]
# #### Evaluate

# %% [markdown]
# **The Evaluation of ROC and AUC for Model without "class_weigth"**

# %%
y_pred_proba = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rates')
plt.ylabel('True Positive Rates')
plt.title('ROC Curve for Keras Model')
plt.show()

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8598984192204532

# %% [markdown]
# **The Evaluation of ROC and AUC for Model with "class_weigth"**

# %%
y_pred_proba = model_weighted.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Keras Model_Weighted')
plt.show()

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8637728637728637

# %% [markdown]
# **The Evaluation of ROC and AUC for GridsearchCV Model"**

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Grid Model')
plt.show()

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.8544954816141257

# %% [markdown]
# ## Final Model and Model Deployment

# %% [markdown]
# **I chose my model with class_weight because I got the best roc_auc_score and recal score in that model.**

# %%
import pickle

pickle.dump(scaler, open("scaler_churn", 'wb'))

# %%
final_model  = Sequential()
final_model.add(Dense(15, activation='relu',input_dim = X_train.shape[1]))
final_model.add(Dense(10, activation='relu'))
final_model.add(Dense(5,  activation = 'relu'))
final_model.add(Dense(1, activation='sigmoid'))
final_model.summary()


# compile the model
opt = Adam(lr = 0.005)

final_model.compile(optimizer = opt, loss = 'binary_crossentropy',metrics = ['accuracy'])

# early stopping 
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 20)

# now we fit our model to training data

class_weight = {0:0.62794349 , 1:2.45398773}

final_model.fit(x=X_train, y=y_train, epochs=250, batch_size=32, validation_data = (X_test, y_test), verbose=1,
                    class_weight=class_weight,
                    callbacks = [early_stop])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 15)                180
#
#  dense_29 (Dense)            (None, 10)                160
#
#  dense_30 (Dense)            (None, 5)                 55
#
#  dense_31 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 250/250 [==============================] - 1s 1ms/step - loss: 0.6474 - accuracy: 0.6020 - val_loss: 0.7236 - val_accuracy: 0.5845
# Epoch 2/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.5564 - accuracy: 0.7239 - val_loss: 0.5267 - val_accuracy: 0.7425
# Epoch 3/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.5066 - accuracy: 0.7586 - val_loss: 0.4318 - val_accuracy: 0.7885
# Epoch 4/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4984 - accuracy: 0.7581 - val_loss: 0.4184 - val_accuracy: 0.8090
# Epoch 5/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4920 - accuracy: 0.7645 - val_loss: 0.4642 - val_accuracy: 0.7695
# Epoch 6/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4872 - accuracy: 0.7666 - val_loss: 0.5049 - val_accuracy: 0.7435
# Epoch 7/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4838 - accuracy: 0.7679 - val_loss: 0.4784 - val_accuracy: 0.7695
# Epoch 8/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7666 - val_loss: 0.5149 - val_accuracy: 0.7420
# Epoch 9/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4804 - accuracy: 0.7615 - val_loss: 0.4824 - val_accuracy: 0.7375
# Epoch 10/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7667 - val_loss: 0.4584 - val_accuracy: 0.7730
# Epoch 11/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4716 - accuracy: 0.7757 - val_loss: 0.4531 - val_accuracy: 0.7790
# Epoch 12/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4700 - accuracy: 0.7691 - val_loss: 0.4411 - val_accuracy: 0.7740
# Epoch 13/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4689 - accuracy: 0.7685 - val_loss: 0.4497 - val_accuracy: 0.7840
# Epoch 14/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.7811 - val_loss: 0.4699 - val_accuracy: 0.7700
# Epoch 15/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7809 - val_loss: 0.4379 - val_accuracy: 0.8020
# Epoch 16/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4669 - accuracy: 0.7804 - val_loss: 0.4242 - val_accuracy: 0.8165
# Epoch 17/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4612 - accuracy: 0.7880 - val_loss: 0.4503 - val_accuracy: 0.7760
# Epoch 18/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.7856 - val_loss: 0.4757 - val_accuracy: 0.7665
# Epoch 19/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4591 - accuracy: 0.7868 - val_loss: 0.4402 - val_accuracy: 0.7935
# Epoch 20/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4582 - accuracy: 0.7821 - val_loss: 0.4507 - val_accuracy: 0.7755
# Epoch 21/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7864 - val_loss: 0.4555 - val_accuracy: 0.7880
# Epoch 22/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7904 - val_loss: 0.4595 - val_accuracy: 0.7750
# Epoch 23/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4547 - accuracy: 0.7886 - val_loss: 0.4756 - val_accuracy: 0.7690
# Epoch 24/250
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.7879 - val_loss: 0.4708 - val_accuracy: 0.7670
# Epoch 24: early stopping

# %%
loss_df = pd.DataFrame(final_model.history.history)

loss_df.plot();

# %%
y_pred = (final_model.predict(X_test) > 0.5).astype("int32")
#y_pred = model.predict_classes(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1209  384]
#  [  82  325]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84      1593
#            1       0.46      0.80      0.58       407
#
#     accuracy                           0.77      2000
#    macro avg       0.70      0.78      0.71      2000
# weighted avg       0.84      0.77      0.79      2000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ## Loading Model and Scaler

# %%
from tensorflow.keras.models import load_model

# %%
model_churn = load_model('model_churn.h5')

scaler_churn = pickle.load(open("scaler_churn", "rb"))

# %% [markdown]
# ### Prediction

# %%
random_ten_customer = df.drop('churn', axis = 1).sample(n=10, random_state=101).iloc[0:10, :]

random_ten_customer
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6676          619   52       8      0.000              2          1
# 6421          616   23       8  73112.950              1          1
# 9834          516   46       6  62212.290              1          0
# 8492          494   28       9 114731.760              2          0
# 9982          655   46       7 137145.120              1          1
# 8844          695   35       7      0.000              2          1
# 7247          582   40       3 110150.430              1          1
# 5862          682   40       4      0.000              2          1
# 3662          632   28       5 118890.810              1          0
# 3457          657   36       8 188241.050              2          0
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 6676               1       123242.110                  0                1
# 6421               1        62733.050                  0                0
# 9834               1       171681.860                  0                0
# 8492               1        79479.740                  0                0
# 9982               0       115146.400                  1                0
# 8844               0       160387.980                  0                1
# 7247               1       191757.650                  1                0
# 5862               1       140745.910                  0                0
# 3662               1       145157.970                  0                0
# 3457               0       183058.510                  0                1
#
#       Gender_Male
# 6676            1
# 6421            1
# 9834            0
# 8492            1
# 9982            0
# 8844            1
# 7247            0
# 5862            1
# 3662            0
# 3457            1

# %%
random_ten_customer = scaler_churn.transform(random_ten_customer)

random_ten_customer
# Out:
# array([[0.538     , 0.45945946, 0.8       , 0.        , 0.33333333,
#         1.        , 1.        , 0.6162115 , 0.        , 1.        ,
#         1.        ],
#        [0.532     , 0.06756757, 0.8       , 0.30669784, 0.        ,
#         1.        , 1.        , 0.3136373 , 0.        , 0.        ,
#         1.        ],
#        [0.332     , 0.37837838, 0.6       , 0.26097121, 0.        ,
#         0.        , 1.        , 0.85843338, 0.        , 0.        ,
#         0.        ],
#        [0.288     , 0.13513514, 0.9       , 0.4812825 , 0.33333333,
#         0.        , 1.        , 0.39737875, 0.        , 0.        ,
#         1.        ],
#        [0.61      , 0.37837838, 0.7       , 0.57530317, 0.        ,
#         1.        , 0.        , 0.57572908, 1.        , 0.        ,
#         0.        ],
#        [0.69      , 0.22972973, 0.7       , 0.        , 0.33333333,
#         1.        , 0.        , 0.80195859, 0.        , 1.        ,
#         1.        ],
#        [0.464     , 0.2972973 , 0.3       , 0.46206451, 0.        ,
#         1.        , 1.        , 0.95882192, 1.        , 0.        ,
#         0.        ],
#        [0.664     , 0.2972973 , 0.4       , 0.        , 0.33333333,
#         1.        , 1.        , 0.70373886, 0.        , 0.        ,
#         1.        ],
#        [0.564     , 0.13513514, 0.5       , 0.49872909, 0.        ,
#         0.        , 1.        , 0.72580126, 0.        , 0.        ,
#         0.        ],
#        [0.614     , 0.24324324, 0.8       , 0.78964292, 0.33333333,
#         0.        , 0.        , 0.91532206, 0.        , 1.        ,
#         1.        ]])

# %%
prediction = pd.DataFrame(model_churn.predict(random_ten_customer) > 0.5, columns=['prediction']).astype("int32")
prediction
# Out:
#    prediction
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# 5           0
# 6           1
# 7           0
# 8           0
# 9           1

# %%
actual = pd.DataFrame(df.sample(n=10, random_state=101)["churn"]).rename({'churn': 'actual'}, axis=1).astype("int32")
actual
# Out:
#       actual
# 6676       0
# 6421       0
# 9834       1
# 8492       0
# 9982       1
# 8844       0
# 7247       1
# 5862       0
# 3662       0
# 3457       1

# %%
pred_df = actual.join(prediction.set_index(actual.index))

pred_df
# Out:
#       actual  prediction
# 6676       0           0
# 6421       0           0
# 9834       1           1
# 8492       0           0
# 9982       1           1
# 8844       0           0
# 7247       1           1
# 5862       0           0
# 3662       0           0
# 3457       1           1

# %%
pred_df['prediction_accuracy'] = pred_df.apply(lambda x: "Correct Pred" if int(x['actual'] == x['prediction']) else "Wrong Pred", axis=1)

pred_df
# Out:
#       actual  prediction prediction_accuracy
# 6676       0           0        Correct Pred
# 6421       0           0        Correct Pred
# 9834       1           1        Correct Pred
# 8492       0           0        Correct Pred
# 9982       1           1        Correct Pred
# 8844       0           0        Correct Pred
# 7247       1           1        Correct Pred
# 5862       0           0        Correct Pred
# 3662       0           0        Correct Pred
# 3457       1           1        Correct Pred

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
